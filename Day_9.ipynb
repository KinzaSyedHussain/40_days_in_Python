# %%
import pandas as pd
import numpy as np

# %%
# Object creation
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df =pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.194741  2.055130 -1.063951  0.781546
# 2013-01-02  2.455849 -0.252211  1.541444 -0.413415
# 2013-01-03  0.076690  0.187644  1.249153  2.115879
# 2013-01-04  0.124114  0.205384  0.184730  1.315127
# 2013-01-05 -0.138343  0.352947  0.377094  0.699980
# 2013-01-06  1.996930  1.697257 -0.207203 -1.572690

# %%
df2 = pd.DataFrame(
    {
        "A" : 1.,
        "B" : pd.Timestamp("20220111"),
        "C" : pd.Series(1, index=list(range(4)), dtype="float32"),
        "D" : np.array([3] * 4, dtype="int32"),
        "E" : pd.Categorical(["girl", "woman", "girl", "woman"]),
        "F" : "females"
    }
)
df2
# Out:
#      A          B    C  D      E        F
# 0  1.0 2022-01-11  1.0  3   girl  females
# 1  1.0 2022-01-11  1.0  3  woman  females
# 2  1.0 2022-01-11  1.0  3   girl  females
# 3  1.0 2022-01-11  1.0  3  woman  females

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.194741  2.055130 -1.063951  0.781546
# 2013-01-02  2.455849 -0.252211  1.541444 -0.413415
# 2013-01-03  0.076690  0.187644  1.249153  2.115879
# 2013-01-04  0.124114  0.205384  0.184730  1.315127
# 2013-01-05 -0.138343  0.352947  0.377094  0.699980

# %%
df.tail(2)
# Out:
#                    A         B         C        D
# 2013-01-05 -0.138343  0.352947  0.377094  0.69998
# 2013-01-06  1.996930  1.697257 -0.207203 -1.57269

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df2.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df.to_numpy()
# Out:
# array([[-0.19474072,  2.05512989, -1.06395133,  0.7815462 ],
#        [ 2.45584919, -0.25221107,  1.54144356, -0.41341547],
#        [ 0.07669007,  0.18764363,  1.24915284,  2.11587879],
#        [ 0.12411359,  0.20538355,  0.18472963,  1.31512676],
#        [-0.13834252,  0.35294723,  0.37709393,  0.69998006],
#        [ 1.99692963,  1.69725725, -0.20720251, -1.57268958]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2022-01-11 00:00:00'), 1.0, 3, 'girl', 'females'],
#        [1.0, Timestamp('2022-01-11 00:00:00'), 1.0, 3, 'woman',
#         'females'],
#        [1.0, Timestamp('2022-01-11 00:00:00'), 1.0, 3, 'girl', 'females'],
#        [1.0, Timestamp('2022-01-11 00:00:00'), 1.0, 3, 'woman',
#         'females']], dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.720083  0.707692  0.346878  0.487738
# std    1.182045  0.934329  0.955587  1.305697
# min   -0.194741 -0.252211 -1.063951 -1.572690
# 25%   -0.084584  0.192079 -0.109219 -0.135067
# 50%    0.100402  0.279165  0.280912  0.740763
# 75%    1.528726  1.361180  1.031138  1.181732
# max    2.455849  2.055130  1.541444  2.115879

# %%
df2.T
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2022-01-11 00:00:00  2022-01-11 00:00:00  2022-01-11 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 girl                woman                 girl
# F              females              females              females
#
#                      3
# A                  1.0
# B  2022-01-11 00:00:00
# C                  1.0
# D                    3
# E                woman
# F              females

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.781546 -1.063951  2.055130 -0.194741
# 2013-01-02 -0.413415  1.541444 -0.252211  2.455849
# 2013-01-03  2.115879  1.249153  0.187644  0.076690
# 2013-01-04  1.315127  0.184730  0.205384  0.124114
# 2013-01-05  0.699980  0.377094  0.352947 -0.138343
# 2013-01-06 -1.572690 -0.207203  1.697257  1.996930

# %%
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2013-01-06  1.996930  1.697257 -0.207203 -1.572690
# 2013-01-05 -0.138343  0.352947  0.377094  0.699980
# 2013-01-04  0.124114  0.205384  0.184730  1.315127
# 2013-01-03  0.076690  0.187644  1.249153  2.115879
# 2013-01-02  2.455849 -0.252211  1.541444 -0.413415
# 2013-01-01 -0.194741  2.055130 -1.063951  0.781546

# %%
df.sort_values(by="B", ascending=True)
# Out:
#                    A         B         C         D
# 2013-01-02  2.455849 -0.252211  1.541444 -0.413415
# 2013-01-03  0.076690  0.187644  1.249153  2.115879
# 2013-01-04  0.124114  0.205384  0.184730  1.315127
# 2013-01-05 -0.138343  0.352947  0.377094  0.699980
# 2013-01-06  1.996930  1.697257 -0.207203 -1.572690
# 2013-01-01 -0.194741  2.055130 -1.063951  0.781546

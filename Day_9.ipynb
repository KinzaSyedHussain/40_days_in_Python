# %%
import pandas as pd
import numpy as np

# %%
# Object creation
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df =pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -2.899365  0.989455  1.865563  0.122781
# 2013-01-02  1.184654 -0.395642  0.903375 -0.297672
# 2013-01-03 -1.310561 -0.483426 -1.150785  0.990892
# 2013-01-04  1.320185 -0.380863 -0.426377  2.330616
# 2013-01-05 -0.647823 -0.627886  0.512900 -0.296358
# 2013-01-06 -1.824642 -1.729643  0.270139  0.676566

# %%
df2 = pd.DataFrame(
    {
        "A" : 1.,
        "B" : pd.Timestamp("20220111"),
        "C" : pd.Series(1, index=list(range(4)), dtype="float32"),
        "D" : np.array([3] * 4, dtype="int32"),
        "E" : pd.Categorical(["girl", "woman", "girl", "woman"]),
        "F" : "females"
    }
)
df2
# Out:
#      A          B    C  D      E        F
# 0  1.0 2022-01-11  1.0  3   girl  females
# 1  1.0 2022-01-11  1.0  3  woman  females
# 2  1.0 2022-01-11  1.0  3   girl  females
# 3  1.0 2022-01-11  1.0  3  woman  females

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -2.899365  0.989455  1.865563  0.122781
# 2013-01-02  1.184654 -0.395642  0.903375 -0.297672
# 2013-01-03 -1.310561 -0.483426 -1.150785  0.990892
# 2013-01-04  1.320185 -0.380863 -0.426377  2.330616
# 2013-01-05 -0.647823 -0.627886  0.512900 -0.296358

# %%
df.tail(2)
# Out:
#                    A         B         C         D
# 2013-01-05 -0.647823 -0.627886  0.512900 -0.296358
# 2013-01-06 -1.824642 -1.729643  0.270139  0.676566

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df2.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df.to_numpy()
# Out:
# array([[-2.89936537,  0.98945515,  1.8655629 ,  0.12278113],
#        [ 1.18465355, -0.39564234,  0.90337513, -0.29767164],
#        [-1.3105615 , -0.48342579, -1.15078521,  0.99089189],
#        [ 1.32018459, -0.3808632 , -0.42637679,  2.33061646],
#        [-0.64782274, -0.62788556,  0.51290044, -0.29635826],
#        [-1.82464193, -1.72964323,  0.27013906,  0.67656591]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2022-01-11 00:00:00'), 1.0, 3, 'girl', 'females'],
#        [1.0, Timestamp('2022-01-11 00:00:00'), 1.0, 3, 'woman',
#         'females'],
#        [1.0, Timestamp('2022-01-11 00:00:00'), 1.0, 3, 'girl', 'females'],
#        [1.0, Timestamp('2022-01-11 00:00:00'), 1.0, 3, 'woman',
#         'females']], dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.696259 -0.438001  0.329136  0.587804
# std    1.679912  0.865927  1.047719  0.998980
# min   -2.899365 -1.729643 -1.150785 -0.297672
# 25%   -1.696122 -0.591771 -0.252248 -0.191573
# 50%   -0.979192 -0.439534  0.391520  0.399674
# 75%    0.726534 -0.384558  0.805756  0.912310
# max    1.320185  0.989455  1.865563  2.330616

# %%
df2.T
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2022-01-11 00:00:00  2022-01-11 00:00:00  2022-01-11 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 girl                woman                 girl
# F              females              females              females
#
#                      3
# A                  1.0
# B  2022-01-11 00:00:00
# C                  1.0
# D                    3
# E                woman
# F              females

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.122781  1.865563  0.989455 -2.899365
# 2013-01-02 -0.297672  0.903375 -0.395642  1.184654
# 2013-01-03  0.990892 -1.150785 -0.483426 -1.310561
# 2013-01-04  2.330616 -0.426377 -0.380863  1.320185
# 2013-01-05 -0.296358  0.512900 -0.627886 -0.647823
# 2013-01-06  0.676566  0.270139 -1.729643 -1.824642

# %%
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2013-01-06 -1.824642 -1.729643  0.270139  0.676566
# 2013-01-05 -0.647823 -0.627886  0.512900 -0.296358
# 2013-01-04  1.320185 -0.380863 -0.426377  2.330616
# 2013-01-03 -1.310561 -0.483426 -1.150785  0.990892
# 2013-01-02  1.184654 -0.395642  0.903375 -0.297672
# 2013-01-01 -2.899365  0.989455  1.865563  0.122781

# %%
df.sort_values(by="B", ascending=True)
# Out:
#                    A         B         C         D
# 2013-01-06 -1.824642 -1.729643  0.270139  0.676566
# 2013-01-05 -0.647823 -0.627886  0.512900 -0.296358
# 2013-01-03 -1.310561 -0.483426 -1.150785  0.990892
# 2013-01-02  1.184654 -0.395642  0.903375 -0.297672
# 2013-01-04  1.320185 -0.380863 -0.426377  2.330616
# 2013-01-01 -2.899365  0.989455  1.865563  0.122781

# %%
df.sort_values(by="B", ascending=False)
# Out:
#                    A         B         C         D
# 2013-01-01 -2.899365  0.989455  1.865563  0.122781
# 2013-01-04  1.320185 -0.380863 -0.426377  2.330616
# 2013-01-02  1.184654 -0.395642  0.903375 -0.297672
# 2013-01-03 -1.310561 -0.483426 -1.150785  0.990892
# 2013-01-05 -0.647823 -0.627886  0.512900 -0.296358
# 2013-01-06 -1.824642 -1.729643  0.270139  0.676566

# %%
df["A"]
# Out:
# 2013-01-01   -2.899365
# 2013-01-02    1.184654
# 2013-01-03   -1.310561
# 2013-01-04    1.320185
# 2013-01-05   -0.647823
# 2013-01-06   -1.824642
# Freq: D, Name: A, dtype: float64

# %%
df[0:2]
# Out:
#                    A         B         C         D
# 2013-01-01 -2.899365  0.989455  1.865563  0.122781
# 2013-01-02  1.184654 -0.395642  0.903375 -0.297672

# %%
df[0:]
# Out:
#                    A         B         C         D
# 2013-01-01 -2.899365  0.989455  1.865563  0.122781
# 2013-01-02  1.184654 -0.395642  0.903375 -0.297672
# 2013-01-03 -1.310561 -0.483426 -1.150785  0.990892
# 2013-01-04  1.320185 -0.380863 -0.426377  2.330616
# 2013-01-05 -0.647823 -0.627886  0.512900 -0.296358
# 2013-01-06 -1.824642 -1.729643  0.270139  0.676566

# %%
# row wise selection
df[0:10]
# Out:
#                    A         B         C         D
# 2013-01-01 -2.899365  0.989455  1.865563  0.122781
# 2013-01-02  1.184654 -0.395642  0.903375 -0.297672
# 2013-01-03 -1.310561 -0.483426 -1.150785  0.990892
# 2013-01-04  1.320185 -0.380863 -0.426377  2.330616
# 2013-01-05 -0.647823 -0.627886  0.512900 -0.296358
# 2013-01-06 -1.824642 -1.729643  0.270139  0.676566

# %%
df.loc[dates[2]]
# Out:
# A   -1.310561
# B   -0.483426
# C   -1.150785
# D    0.990892
# Name: 2013-01-03 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01 -2.899365  0.989455
# 2013-01-02  1.184654 -0.395642
# 2013-01-03 -1.310561 -0.483426
# 2013-01-04  1.320185 -0.380863
# 2013-01-05 -0.647823 -0.627886
# 2013-01-06 -1.824642 -1.729643

# %%
df.loc["20130102":"20220104", ["A", "B", "C"]]
# Out:
#                    A         B         C
# 2013-01-02  1.184654 -0.395642  0.903375
# 2013-01-03 -1.310561 -0.483426 -1.150785
# 2013-01-04  1.320185 -0.380863 -0.426377
# 2013-01-05 -0.647823 -0.627886  0.512900
# 2013-01-06 -1.824642 -1.729643  0.270139

# %%
df.loc["20130102", ["A", "B", "C"]]
# Out:
# A    1.184654
# B   -0.395642
# C    0.903375
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.at[dates[0], "A"]
# Out:
# -2.8993653736206735

# %%
df.iloc[3:10]
# Out:
#                    A         B         C         D
# 2013-01-04  1.320185 -0.380863 -0.426377  2.330616
# 2013-01-05 -0.647823 -0.627886  0.512900 -0.296358
# 2013-01-06 -1.824642 -1.729643  0.270139  0.676566

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  1.320185 -0.380863
# 2013-01-05 -0.647823 -0.627886

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-02  1.184654 -0.395642  0.903375 -0.297672
# 2013-01-04  1.320185 -0.380863 -0.426377  2.330616

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN  0.989455  1.865563  0.122781
# 2013-01-02  1.184654       NaN  0.903375       NaN
# 2013-01-03       NaN       NaN       NaN  0.990892
# 2013-01-04  1.320185       NaN       NaN  2.330616
# 2013-01-05       NaN       NaN  0.512900       NaN
# 2013-01-06       NaN       NaN  0.270139  0.676566

# %%
df2 = df.copy()

# %%
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -2.899365  0.989455  1.865563  0.122781    one
# 2013-01-02  1.184654 -0.395642  0.903375 -0.297672    one
# 2013-01-03 -1.310561 -0.483426 -1.150785  0.990892    two
# 2013-01-04  1.320185 -0.380863 -0.426377  2.330616  three
# 2013-01-05 -0.647823 -0.627886  0.512900 -0.296358   four
# 2013-01-06 -1.824642 -1.729643  0.270139  0.676566  three

# %%
df2["mean"] = [1.2, 2.3, 3., 4.5, 2.5, np.nan]
df2 = df2.iloc[:, 0:4]
df2
# Out:
#                    A         B         C         D
# 2013-01-01 -2.899365  0.989455  1.865563  0.122781
# 2013-01-02  1.184654 -0.395642  0.903375 -0.297672
# 2013-01-03 -1.310561 -0.483426 -1.150785  0.990892
# 2013-01-04  1.320185 -0.380863 -0.426377  2.330616
# 2013-01-05 -0.647823 -0.627886  0.512900 -0.296358
# 2013-01-06 -1.824642 -1.729643  0.270139  0.676566
